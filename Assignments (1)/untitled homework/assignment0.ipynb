# %%
# this imports stuff after downloading
# %pip install numpy pynum jax einsteinpy scipy sympy pygame
import pygame 
import sympy
import jax 
import einsteinpy
import pynum
import scipy
import numpy

#using function with variable inputs

y= "python is awesome" 
x= "worse than c++ for game engines (compiler >> interpreter)"

def truestatement1(x):
      print("python is " + x)

truestatement1(x)
truestatement1(y)
def truestatement2(x_1):
      print("python is " + x_1)

z=1 
w=0

def truestatement3(v):
    return(v) 

truestatement3(w) 
 #write python program to do father and son's age to accept father and sons age and then add it
age_f= int(input("enter age of father "))
print(age_f)

age_s= int(input("enter age of son "))
print(age_s)

age_sum= age_f + age_s
print("combined age of father and son is   " + str(age_sum))


 print("idiot",  end(,))
a=((1,2,3),(4,2,1),(1,2,0))
a[1]
a[1][2]
#write a mutable tuple
print(len(a))
print(type(a))
#tuple constructor
print("combined age of father and son is   " + str(age_sum
# Out:
#   Cell In[1], line 34
#     print("idiot",  end(,))
#     ^
# IndentationError: unexpected indent
